# %% [markdown]
# ##Environment Setup

# %%
# !pip install openai diffusers torch transformers
import os
import openai
import pandas as pd
import torch
from diffusers import StableDiffusionPipeline
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 1.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 72.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 59.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 59.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 10.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 6.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 58.7 MB/s eta 0:00:00
# ...
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
# ...

# %% [markdown]
# ## Task3

# %%
# OpenAI API Key (Set your key here)
openai.api_key = "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"

# Load Stable Diffusion model
sd_pipe = StableDiffusionPipeline.from_pretrained("runwayml/stable-diffusion-v1-5")
sd_pipe.to("cuda" if torch.cuda.is_available() else "cpu")

# Function to generate an image using OpenAI's DALL·E
def generate_dalle_image(prompt):
    response = openai.images.generate(
        model="dall-e-3",  # Use "dall-e-2" if needed
        prompt=prompt,
        n=1,
        size="1024x1024"
    )
    return response.data[0].url  # Use dot notation


# Function to generate an image using Stable Diffusion
import hashlib

def generate_stable_diffusion_image(prompt):
    image = sd_pipe(prompt).images[0]
    hash_object = hashlib.md5(prompt.encode())
    image_path = f"{hash_object.hexdigest()}.png"
    image.save(image_path)
    return image_path
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# model_index.json:   0%|          | 0.00/541 [00:00<?, ?B/s]
# Fetching 15 files:   0%|          | 0/15 [00:00<?, ?it/s]
# model.safetensors:   0%|          | 0.00/1.22G [00:00<?, ?B/s]
# safety_checker%2Fconfig.json:   0%|          | 0.00/4.72k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/492M [00:00<?, ?B/s]
# tokenizer%2Fspecial_tokens_map.json:   0%|          | 0.00/472 [00:00<?, ?B/s]
# ...

# %%
# Product Prompts
lego_prompt = "The set includes a blue-uniformed police officer minifigure equipped with a walkie-talkie and handcuffs. The LEGO City Police Car toy is designed for kids, featuring a detailed, modern police vehicle aesthetic with realistic elements. It is fully compatible with other LEGO sets, allowing for customization and expansion. Built from durable ABS plastic, the car is sturdy, impact-resistant, and designed to withstand active play, ensuring longevity."
bunny_light_prompt = "cute and squishy bunny-shaped night light made of soft, BPA-free, non-toxic silicone. The lamp emits a warm, evenly diffused glow that spreads across the entire bunny shape, ensuring a comforting atmosphere. It features touch-sensitive controls and adjustable brightness for personalized lighting. The night light offers multiple color-changing modes and an auto shut-off timer for convenience. Designed to be rechargeable via USB, it is safe for all ages and built to be drop-resistant."
bonnet_prompt = "luxurious double-layered satin bonnet for women's hair protection, made of smooth, breathable silk with a slight gloss. Lightweight yet structured, it drapes naturally while maintaining shape. A soft elastic band ensures a snug fit, keeping it secure overnight. The dome design fully encloses hair, preventing frizz and moisture loss. Available in multiple colors and sizes, with neatly stitched seams. To wear, gather hair inside and tuck under the band. Machine washable, retaining elasticity and sheen over time."

# Generate Images with DALL·E
lego_dalle = generate_dalle_image(lego_prompt)
bunny_light_dalle = generate_dalle_image(bunny_light_prompt)
bonnet_dalle = generate_dalle_image(bonnet_prompt)

# Generate Images with Stable Diffusion
lego_sd = generate_stable_diffusion_image(lego_prompt)
bunny_light_sd = generate_stable_diffusion_image(bunny_light_prompt)
bonnet_sd = generate_stable_diffusion_image(bonnet_prompt)

# Print Image Paths
print("LEGO Police Car (DALL·E):", lego_dalle)
print("LEGO Police Car (Stable Diffusion):", lego_sd)

print("Bunny Night Light (DALL·E):", bunny_light_dalle)
print("Bunny Night Light (Stable Diffusion):", bunny_light_sd)

print("Silk Bonnet (DALL·E):", bonnet_dalle)
print("Silk Bonnet (Stable Diffusion):", bonnet_sd)
# Out:
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['resistant , and designed to withstand active play , ensuring longevity .']
#   0%|          | 0/50 [00:00<?, ?it/s]
# LEGO Police Car (DALL·E): https://oaidalleapiprodscus.blob.core.windows.net/private/org-4ic4uumzK1O7L3KpztkHnlG1/user-FUpiwczYqYDh4qy92Fu8qSji/img-RiEojQwN3dMTbrvZ8SjjbY4Y.png?st=2025-02-24T21%3A12%3A50Z&se=2025-02-24T23%3A12%3A50Z&sp=r&sv=2024-08-04&sr=b&rscd=inline&rsct=image/png&skoid=d505667d-d6c1-4a0a-bac7-5c84a87759f8&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2025-02-24T03%3A13%3A50Z&ske=2025-02-25T03%3A13%3A50Z&sks=b&skv=2024-08-04&sig=AohBAsX8Q6%2BoJ/n5vqgEQDjJwsx2lyMD8X49qGKI6nc%3D
# LEGO Police Car (Stable Diffusion): 0e52af363ed0309f57c35931e72a4e0a.png
